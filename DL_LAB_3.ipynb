# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajendra9692385543/Data-Analytics-and-Machine-Learning/blob/Deep-Learning/DL_LAB_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Experiment 3 : Weight updation using Backpropagation with a sample data

# %%
import numpy as np

# %%
# Define the data (input, expected Output)
X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([0,0,0,1])

# %%
# Define Weights and biases (initialize randomly)
weights1=np.random.rand(2,3) # Weights for 1st hidden layer (2 inputs, 3 hidden neurons)
bias1=np.random.rand(3) # Bias for 1st hidden layer

weights2=np.random.rand(3,1) # Weights for 2nd hidden layer (3 hidden neurons, 1 output)
bias2=np.random.rand() # Bias for 2nd hidden layer

# Define the learning rate
learning_rate = 0.1

# %%
# Function for calculating the sigmoid activation
def sigmoid(x):
  return 1/(1+np.exp(-x))

# Function for calculating the  derivative of sigmoid (used later)
def sigmoid_derivative(x):
  return sigmoid(x)*(1-sigmoid(x))

# Iterate over all data points for multiple updates
for i in range(len(X)):
  x=X[i] # Input values
  target =y[i] # Expected output

# %%
# Forward Pass
# 1st Hidden Layer
z1=np.dot(x,weights1)+bias1 # Weighted sum for 1st hidden layer
a1 = sigmoid(z1) # Activation for 1st hidden layer
# 2nd Hidden Layer
z2 =np.dot(a1,weights2)+bias2 # Weighted sum for 2nd hidden layer
a2 = sigmoid(z2) # Activation for 2nd hidden layer (output layer in this case)
# Output
output=a2
# Calculate the error
error = target - output

# %%
# Backpropagation
# Output layer derivative
output_derivative = sigmoid_derivative(a2)
#Propagate error back to 2nd hidden layer
hidden2_derivative = output_derivative * error
# Update weights and bias for 2nd hidden layer
weights2_derivative = np.dot(a1.reshape(-1, 1), hidden2_derivative.reshape(1, -1))
weights2 -= learning_rate * weights2_derivative
bias2 -= learning_rate * hidden2_derivative
# Propagate error back to 1st hidden layer
# Change is here! Transpose hidden2_derivative to match the dimensions for dot product
hidden1_derivative = np.dot(weights2, hidden2_derivative) * sigmoid_derivative(z1)
# No need to reshape hidden2_derivative

# %%
# Update weights and bias for 1st hidden layer
weights1_derivative = np.dot(x.reshape(-1, 1), hidden1_derivative.reshape(1, -1))  # Reshape hidden1_derivative instead
weights1 -= learning_rate * weights1_derivative
bias1 -= learning_rate * hidden1_derivative.reshape(bias1.shape)  # Reshape the derivative to match bias1's shape
# Print the results after iterating through all data points
print("Initial Weights (Hidden Layer 1):", weights1)
print("Initial Bias (Hidden Layer 1):", bias1)
print("Initial Weights (Hidden Layer 2):", weights2)
print("Initial Bias (Hidden Layer 2):", bias2)
print("\nUpdated Weights (Hidden Layer 1) after Backpropagation:", weights1)
print("Updated Bias (Hidden Layer 1) after Backpropagation:", bias1)
print("Updated Weights (Hidden Layer 2) after Backpropagation:", weights2)
print("Updated Bias (Hidden Layer 2) after Backpropagation:", bias2)
# Out:
# Initial Weights (Hidden Layer 1): [[0.00766935 0.70408057 0.36783781]
#  [0.24040552 0.24665327 0.56843156]]
# Initial Bias (Hidden Layer 1): [0.2452     0.9718519  0.87238928]
# Initial Weights (Hidden Layer 2): [[0.397901  ]
#  [0.77528189]
#  [0.71421238]]
# Initial Bias (Hidden Layer 2): [0.05139408]
#
# Updated Weights (Hidden Layer 1) after Backpropagation: [[0.00766935 0.70408057 0.36783781]
#  [0.24040552 0.24665327 0.56843156]]
# Updated Bias (Hidden Layer 1) after Backpropagation: [0.2452     0.9718519  0.87238928]
# Updated Weights (Hidden Layer 2) after Backpropagation: [[0.397901  ]
#  [0.77528189]
#  [0.71421238]]
# Updated Bias (Hidden Layer 2) after Backpropagation: [0.05139408]

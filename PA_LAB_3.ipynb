# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajendra9692385543/Data-Analytics-and-Machine-Learning/blob/Machine-Learning/PA_LAB_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **NER**

# %%
import nltk
from nltk import word_tokenizer, pos_tag,

input = "Barak Obama went"
